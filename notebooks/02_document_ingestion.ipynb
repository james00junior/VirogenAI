# %% [markdown]
# # VirogenAI — 02. Document Ingestion
#
# Prepare verified source documents for domain-specific retrieval. Full PDF/table extraction will be implemented only after the inventory confirms the available formats.

# %%
from rag.config import DOMAINS

for domain in DOMAINS:
    print(domain.name, '->', domain.description)
